# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
import re
import time
from selenium.webdriver.common.by import By
import requests
import pandas as pd
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException

#request user input for LinkedIn username and password:
print("Please enter the exact LinkedIn username you use to login (email/phone?):")
username_string = str(input())
print()
print("Please enter the exact LinkedIn password:")
password_string = str(input())
print()
# print("Please enter your usernmae exactly how it appears in your profile link (after '/in') :")
# link_username = str(input())
# print()


#create a browser-specific (Google Chrome) web navigation simulator:
service = Service()
options = webdriver.ChromeOptions()
browser = webdriver.Chrome(service=service, options=options)

#open the LinkedIn login page and login under a specified account:
browser.get('https://www.linkedin.com/login')
#enter the specified information to login to LinkedIn:
elementID = browser.find_element(By.ID,'username')
elementID.send_keys(username_string)
elementID = browser.find_element(By.ID,'password')
elementID.send_keys(password_string)
elementID.submit()

# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By
import time


# List of URLs
urls = [
    "https://www.linkedin.com/posts/surojitmahato_websites-to-download-free-videos-by-surojit-activity-7093433142757269505-e14u?utm_source=share&utm_medium=member_desktop",
    "https://www.linkedin.com/posts/surojitmahato_tools-to-remove-watermark-by-surojit-activity-7093089542596915200-ffMG?utm_source=share&utm_medium=member_desktop",
    "https://www.linkedin.com/posts/surojitmahato_tips-to-write-caption-by-surojit-activity-7092725671533133824-sMdh?utm_source=share&utm_medium=member_desktop",
    "https://www.linkedin.com/posts/surojitmahato_best-video-editing-tools-by-surojit-activity-7092359970641354752-pxST?utm_source=share&utm_medium=member_desktop",
    "https://www.linkedin.com/posts/surojitmahato_youtube-channels-to-learn-smm-by-surojit-activity-7092002463083376640-bPnr?utm_source=share&utm_medium=member_desktop",
    "https://www.linkedin.com/posts/surojitmahato_how-to-use-linkedin-better-by-surojit-activity-7091634833717686272-E_yk?utm_source=share&utm_medium=member_desktop",
    "https://www.linkedin.com/posts/surojitmahato_best-ai-tools-for-writers-by-surojit-activity-7091258606699905024-J1mh?utm_source=share&utm_medium=member_desktop",
    "https://www.linkedin.com/posts/surojitmahato_websites-to-get-free-stock-photos-by-surojit-activity-7090911030234550273-HVQt?utm_source=share&utm_medium=member_desktop",
    "https://www.linkedin.com/posts/surojitmahato_key-components-of-digital-marketing-by-surojit-activity-7090549746553024514-Ss-E?utm_source=share&utm_medium=member_desktop",
    "https://www.linkedin.com/posts/surojitmahato_books-to-read-for-entrepreneurs-by-surojit-activity-7090195720904871937-rrTI?utm_source=share&utm_medium=member_desktop",
    "https://www.linkedin.com/posts/surojitmahato_influencers-to-follow-as-a-marketer-by-surojit-activity-7089829383279939584-BqLC?utm_source=share&utm_medium=member_desktop",
    "https://www.linkedin.com/posts/surojitmahato_social-media-content-calendar-by-surojit-activity-7089462296934051840-BpSR?utm_source=share&utm_medium=member_desktop",
    "https://www.linkedin.com/posts/surojitmahato_free-video-making-tools-by-surojit-activity-7089095268456960000-yzAk?utm_source=share&utm_medium=member_desktop",
    "https://www.linkedin.com/posts/surojitmahato_best-ai-tools-for-research-by-surojit-activity-7088721897030385664-4b9p?utm_source=share&utm_medium=member_desktop",
    "https://www.linkedin.com/posts/surojitmahato_types-of-blog-post-by-surojit-activity-7088359505368936448-yhtH?utm_source=share&utm_medium=member_desktop",
    "https://www.linkedin.com/posts/surojitmahato_websites-to-download-free-fonts-by-surojit-activity-7088012047577206784-U3Sb?utm_source=share&utm_medium=member_desktop",
    "https://www.linkedin.com/posts/surojitmahato_how-to-create-a-strong-linkedin-profile-by-activity-7087659279926636544-iK2L?utm_source=share&utm_medium=member_desktop",
    "https://www.linkedin.com/posts/surojitmahato_ai-tools-for-productivity-by-surojit-activity-7087272349938434048-_ohA?utm_source=share&utm_medium=member_desktop",
    "https://www.linkedin.com/posts/surojitmahato_in-2015-if-someone-told-me-that-8-years-activity-7087031006586671104-mafB?utm_source=share&utm_medium=member_desktop",
    "https://www.linkedin.com_posts/surojitmahato_how-to-find-a-job-in-linkedin-by-surojit-activity-7086909966279655424-CbXy?utm_source=share&utm_medium=member_desktop",
    "https://www.linkedin.com/posts/surojitmahato_dear-job-seekers-never-hesitate-to-reach-activity-7086648519956074496-R7Qi?utm_source=share&utm_medium=member_desktop",
    "https://www.linkedin.com/posts/surojitmahato_best-ai-tools-for-designers-by-surojit-activity-7086547579705966592-PuRQ?utm_source=share&utm_medium=member_desktop",
    "https://www.linkedin.com/posts/surojitmahato_improve-your-writing-skills-by-surojit-activity-7086185186140311552-7Udc?utm_source=share&utm_medium=member_desktop",
    "https://www.linkedin.com/posts/surojitmahato_questions-to-ask-yourself-for-linkedin-post-activity-7085822790464901120-DGEQ?utm_source=share&utm_medium=member_desktop",
    "https://www.linkedin.com/posts/surojitmahato_how-to-approach-recruiters-for-a-job-opportunity-activity-7085567314984644608-RPB1?utm_source=share&utm_medium=member_desktop"
]
   

# List to store extracted values and URLs
captions = []
likers = []
# reposts = []
comments = []
Url = []

# Iterate over the URLs
for url in urls:
    browser.get(url)
    time.sleep(1)

    # Initialize variables for extracted values
    comments_value = None
#     reposts_value = None
    likes_value = None
    captions_value=None
    
    try:
        see_more_btn = browser.find_element(By.CLASS_NAME, 'see-more.inline')
        see_more_btn.click()
        time.sleep(2)
    except NoSuchElementException:
        pass

    # Extract the caption
    try:
        caption_element = browser.find_element(By.XPATH, '//div[contains(@class,"update-components-text relative feed-shared-update-v2__commentary ")]')
        caption = caption_element.text
        captions.append(caption)
    except NoSuchElementException:
        captions.append("Caption not found")

    try:
        # Find the comments element
        comments_element = browser.find_element(By.XPATH, "//button[contains(@aria-label, 'comments') or contains(@aria-label, 'comment')][contains(concat(' ', normalize-space(@class), ' '), ' t-black--light social-details-social-counts__count-value t-12 hoverable-link-text ')]")
        span = comments_element.find_element(By.TAG_NAME, "span")
        comments_value = span.text
    except NoSuchElementException:
        print("comments not found for:", url)

#     try:
#         # Find the reposts element
#         reposts_element = browser.find_element(By.XPATH, "//button[contains(@aria-label, 'reposts') or contains(@aria-label, 'repost')][contains(concat(' ', normalize-space(@class), ' '), ' ember-view t-black--light t-12 hoverable-link-text ')]")
#         span = reposts_element.find_element(By.TAG_NAME, "span")
#         reposts_value = span.text
#     except NoSuchElementException:
#         print("reposts not found for:", url)

    try:
        # Find the likes element
        likes_element = browser.find_element(By.CLASS_NAME, "social-details-social-counts__count-value")
        likes_value = likes_element.text
    except NoSuchElementException:
        print("likes not found for:", url)

    # Append the extracted values and URL to the lists
    likers.append(likes_value)
#     reposts.append(reposts_value)
    comments.append(comments_value)
#     captions.append(captions_value)
    Url.append(url)

# Print the extracted values and URLs
# for captions, liker, repost, comment, url in zip(captions, likers, reposts, comments, Url):
# for caption, liker, comment, url in zip(captions, likers, comments, Url):
#     print("Captions:",captions)
#     print("Likers:", liker)
# #     print("Reposts:", repost)
#     print("Comments:", comment)
#     print("URL:", url)
#     print()

    
# Quit the driver
browser.quit()

# %%
import pandas as pd

# Your data
data = {
    'No._of_Likes': likers,
    'No._of_Comments': comments,
    'captions':captions,
#     'No._of_Reposts': reposts,
    'URL of Post': Url
}

# Create DataFrame
df = pd.DataFrame(data)

# Save DataFrame to Excel file
df.to_excel("surojitmahato.xlsx", index=False)  # Change the filename as needed
